# %%
import os
import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir(r'D:\On-job-Training')

# %%
import pandas as pd

# %%
data=pd.read_csv('NYPD_Shooting_Incident_Data__Historic_.csv')

# %%
data.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME    BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0     228798151  05/27/2021   21:30:00  QUEENS               NaN       105
# 1     137471050  06/27/2014   17:40:00   BRONX               NaN        40
# 2     147998800  11/21/2015   03:56:00  QUEENS               NaN       108
# 3     146837977  10/09/2015   18:30:00   BRONX               NaN        44
# 4      58921844  02/19/2009   22:58:00   BRONX               NaN        47
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0                NaN           NaN
# 1                0.0                NaN           NaN
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG  ... PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# 0                    False  ...      NaN       NaN         18-24       M
# ...

# %%
data=data.drop(columns='INCIDENT_KEY')

# %%
data.head()
# Out:
#    OCCUR_DATE OCCUR_TIME    BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0  05/27/2021   21:30:00  QUEENS               NaN       105
# 1  06/27/2014   17:40:00   BRONX               NaN        40
# 2  11/21/2015   03:56:00  QUEENS               NaN       108
# 3  10/09/2015   18:30:00   BRONX               NaN        44
# 4  02/19/2009   22:58:00   BRONX               NaN        47
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0                NaN           NaN
# 1                0.0                NaN           NaN
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG PERP_AGE_GROUP PERP_SEX PERP_RACE VIC_AGE_GROUP  \
# 0                    False            NaN      NaN       NaN         18-24
# 1                    False            NaN      NaN       NaN         18-24
# ...

# %%
data['OCCUR_DATE']= pd.to_datetime(data['OCCUR_DATE'])

# %%
data['OCCUR_DATE']
# Out:
# 0       2021-05-27
# 1       2014-06-27
# 2       2015-11-21
# 3       2015-10-09
# 4       2009-02-19
#            ...
# 27307   2022-05-14
# 27308   2022-01-22
# 27309   2022-06-18
# 27310   2022-06-19
# 27311   2022-01-28
# Name: OCCUR_DATE, Length: 27312, dtype: datetime64[ns]

# %%
data['Year']= data['OCCUR_DATE'].dt.year
data['Month'] = data['OCCUR_DATE'].dt.month
data['Day'] = data['OCCUR_DATE'].dt.dayofweek

# %%
data.head()
# Out:
#   OCCUR_DATE OCCUR_TIME    BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0 2021-05-27   21:30:00  QUEENS               NaN       105
# 1 2014-06-27   17:40:00   BRONX               NaN        40
# 2 2015-11-21   03:56:00  QUEENS               NaN       108
# 3 2015-10-09   18:30:00   BRONX               NaN        44
# 4 2009-02-19   22:58:00   BRONX               NaN        47
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0                NaN           NaN
# 1                0.0                NaN           NaN
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG PERP_AGE_GROUP  ... VIC_SEX        VIC_RACE  \
# 0                    False            NaN  ...       M           BLACK
# 1                    False            NaN  ...       M           BLACK
# ...

# %%
data['Hour'] = data['OCCUR_TIME'].apply(lambda x: int(str(x).split(':')[0]))

# %%
data.head()
# Out:
#   OCCUR_DATE OCCUR_TIME    BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0 2021-05-27   21:30:00  QUEENS               NaN       105
# 1 2014-06-27   17:40:00   BRONX               NaN        40
# 2 2015-11-21   03:56:00  QUEENS               NaN       108
# 3 2015-10-09   18:30:00   BRONX               NaN        44
# 4 2009-02-19   22:58:00   BRONX               NaN        47
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0                NaN           NaN
# 1                0.0                NaN           NaN
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG PERP_AGE_GROUP  ...        VIC_RACE    X_COORD_CD  \
# 0                    False            NaN  ...           BLACK  1.058925e+06
# 1                    False            NaN  ...           BLACK  1.005028e+06
# ...

# %%
df=data.copy()

# %%
df.head()
# Out:
#   OCCUR_DATE OCCUR_TIME    BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0 2021-05-27   21:30:00  QUEENS               NaN       105
# 1 2014-06-27   17:40:00   BRONX               NaN        40
# 2 2015-11-21   03:56:00  QUEENS               NaN       108
# 3 2015-10-09   18:30:00   BRONX               NaN        44
# 4 2009-02-19   22:58:00   BRONX               NaN        47
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0                NaN           NaN
# 1                0.0                NaN           NaN
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG PERP_AGE_GROUP  ...        VIC_RACE    X_COORD_CD  \
# 0                    False            NaN  ...           BLACK  1.058925e+06
# 1                    False            NaN  ...           BLACK  1.005028e+06
# ...

# %%
import numpy as np
df['HOUR_SIN'] = np.sin(2 * np.pi * df['Hour'] / 24)
df['HOUR_COS'] = np.cos(2 * np.pi * df['Hour'] / 24)
df['MONTH_SIN'] = np.sin(2 * np.pi * df['Month'] / 12)
df['MONTH_COS'] = np.cos(2 * np.pi * df['Month'] / 12)
df['DAY_OF_WEEK_SIN'] = np.sin(2 * np.pi * df['Day'] / 7)
df['DAY_OF_WEEK_COS'] = np.cos(2 * np.pi * df['Day'] / 7)

# %%
df.head()
# Out:
#   OCCUR_DATE OCCUR_TIME    BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0 2021-05-27   21:30:00  QUEENS               NaN       105
# 1 2014-06-27   17:40:00   BRONX               NaN        40
# 2 2015-11-21   03:56:00  QUEENS               NaN       108
# 3 2015-10-09   18:30:00   BRONX               NaN        44
# 4 2009-02-19   22:58:00   BRONX               NaN        47
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0                NaN           NaN
# 1                0.0                NaN           NaN
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG PERP_AGE_GROUP  ...  Year Month Day Hour  HOUR_SIN  \
# 0                    False            NaN  ...  2021     5   3   21 -0.707107
# 1                    False            NaN  ...  2014     6   4   17 -0.965926
# ...

# %%
df2=df.copy()

# %%
print(df2.columns.tolist())
# Out:
# ['OCCUR_DATE', 'OCCUR_TIME', 'BORO', 'LOC_OF_OCCUR_DESC', 'PRECINCT', 'JURISDICTION_CODE', 'LOC_CLASSFCTN_DESC', 'LOCATION_DESC', 'STATISTICAL_MURDER_FLAG', 'PERP_AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'VIC_AGE_GROUP', 'VIC_SEX', 'VIC_RACE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude', 'Lon_Lat', 'Year', 'Month', 'Day', 'Hour', 'HOUR_SIN', 'HOUR_COS', 'MONTH_SIN', 'MONTH_COS', 'DAY_OF_WEEK_SIN', 'DAY_OF_WEEK_COS']

# %%
df2 = df.drop(columns=['OCCUR_DATE', 'OCCUR_TIME', 'Day', 'Month', 'Hour'])

# %%
print(df2.columns.tolist())
# Out:
# ['BORO', 'LOC_OF_OCCUR_DESC', 'PRECINCT', 'JURISDICTION_CODE', 'LOC_CLASSFCTN_DESC', 'LOCATION_DESC', 'STATISTICAL_MURDER_FLAG', 'PERP_AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'VIC_AGE_GROUP', 'VIC_SEX', 'VIC_RACE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude', 'Lon_Lat', 'Year', 'HOUR_SIN', 'HOUR_COS', 'MONTH_SIN', 'MONTH_COS', 'DAY_OF_WEEK_SIN', 'DAY_OF_WEEK_COS']

# %%
df2.head()
# Out:
#      BORO LOC_OF_OCCUR_DESC  PRECINCT  JURISDICTION_CODE LOC_CLASSFCTN_DESC  \
# 0  QUEENS               NaN       105                0.0                NaN
# 1   BRONX               NaN        40                0.0                NaN
# 2  QUEENS               NaN       108                0.0                NaN
# 3   BRONX               NaN        44                0.0                NaN
# 4   BRONX               NaN        47                0.0                NaN
#
#   LOCATION_DESC  STATISTICAL_MURDER_FLAG PERP_AGE_GROUP PERP_SEX PERP_RACE  \
# 0           NaN                    False            NaN      NaN       NaN
# 1           NaN                    False            NaN      NaN       NaN
# 2           NaN                     True            NaN      NaN       NaN
# 3           NaN                    False            NaN      NaN       NaN
# 4           NaN                     True          25-44        M     BLACK
#
# ...

# %%
df2.isnull().sum()
# Out:
# BORO                           0
# LOC_OF_OCCUR_DESC          25596
# PRECINCT                       0
# JURISDICTION_CODE              2
# LOC_CLASSFCTN_DESC         25596
# LOCATION_DESC              14977
# STATISTICAL_MURDER_FLAG        0
# PERP_AGE_GROUP              9344
# PERP_SEX                    9310
# PERP_RACE                   9310
# VIC_AGE_GROUP                  0
# VIC_SEX                        0
# VIC_RACE                       0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                      10
# Longitude                     10
# Lon_Lat                       10
# Year                           0
# HOUR_SIN                       0
# HOUR_COS                       0
# MONTH_SIN                      0
# MONTH_COS                      0
# DAY_OF_WEEK_SIN                0
# DAY_OF_WEEK_COS                0
# dtype: int64

# %%
df2.shape
# Out:
# (27312, 25)

# %%
df2 = df2.drop(columns=['LOC_OF_OCCUR_DESC','LOC_CLASSFCTN_DESC'])

# %%
df2.shape
# Out:
# (27312, 23)

# %%
df2.isnull().sum()
# Out:
# BORO                           0
# PRECINCT                       0
# JURISDICTION_CODE              2
# LOCATION_DESC              14977
# STATISTICAL_MURDER_FLAG        0
# PERP_AGE_GROUP              9344
# PERP_SEX                    9310
# PERP_RACE                   9310
# VIC_AGE_GROUP                  0
# VIC_SEX                        0
# VIC_RACE                       0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                      10
# Longitude                     10
# Lon_Lat                       10
# Year                           0
# HOUR_SIN                       0
# HOUR_COS                       0
# MONTH_SIN                      0
# MONTH_COS                      0
# DAY_OF_WEEK_SIN                0
# DAY_OF_WEEK_COS                0
# dtype: int64

# %%
# Example: How many rows are missing all 3?
df2[['PERP_AGE_GROUP', 'PERP_SEX', 'PERP_RACE']].isnull().all(axis=1).sum()
# Out:
# 9310

# %%
df2['PERP_RACE'].value_counts()
# Out:
# PERP_RACE
# BLACK                             11432
# WHITE HISPANIC                     2341
# UNKNOWN                            1836
# BLACK HISPANIC                     1314
# (null)                              640
# WHITE                               283
# ASIAN / PACIFIC ISLANDER            154
# AMERICAN INDIAN/ALASKAN NATIVE        2
# Name: count, dtype: int64

# %%
df2['PERP_SEX'].value_counts()
# Out:
# PERP_SEX
# M         15439
# U          1499
# (null)      640
# F           424
# Name: count, dtype: int64

# %%
df2['PERP_AGE_GROUP'].value_counts()
# Out:
# PERP_AGE_GROUP
# 18-24      6222
# 25-44      5687
# UNKNOWN    3148
# <18        1591
# (null)      640
# 45-64       617
# 65+          60
# 940           1
# 224           1
# 1020          1
# Name: count, dtype: int64

# %%
df2['PERP_AGE_GROUP'] = df2['PERP_AGE_GROUP'].replace({
    '940': 'UNKNOWN',
    '224': 'UNKNOWN',
    '1020': 'UNKNOWN',
    '(null)': 'UNKNOWN'
})

# %%
df2['PERP_AGE_GROUP'].value_counts()
# Out:
# PERP_AGE_GROUP
# 18-24      6222
# 25-44      5687
# UNKNOWN    3791
# <18        1591
# 45-64       617
# 65+          60
# Name: count, dtype: int64

# %%
df2['PERP_SEX'] = df2['PERP_SEX'].replace({'(null)': 'UNKNOWN', 'U': 'UNKNOWN'})

# %%
df2['PERP_SEX'].value_counts()
# Out:
# PERP_SEX
# M          15439
# UNKNOWN     2139
# F            424
# Name: count, dtype: int64

# %%
df2['PERP_RACE'] = df2['PERP_RACE'].replace('(null)', 'UNKNOWN')
df2['PERP_RACE'] = df2['PERP_RACE'].replace({
    'AMERICAN INDIAN/ALASKAN NATIVE': 'OTHER',
    'ASIAN / PACIFIC ISLANDER': 'OTHER'
})

# %%
df2['PERP_RACE'].value_counts()
# Out:
# PERP_RACE
# BLACK             11432
# UNKNOWN            2476
# WHITE HISPANIC     2341
# BLACK HISPANIC     1314
# WHITE               283
# OTHER               156
# Name: count, dtype: int64

# %%
df2.isnull().sum()
# Out:
# BORO                           0
# PRECINCT                       0
# JURISDICTION_CODE              2
# LOCATION_DESC              14977
# STATISTICAL_MURDER_FLAG        0
# PERP_AGE_GROUP              9344
# PERP_SEX                    9310
# PERP_RACE                   9310
# VIC_AGE_GROUP                  0
# VIC_SEX                        0
# VIC_RACE                       0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                      10
# Longitude                     10
# Lon_Lat                       10
# Year                           0
# HOUR_SIN                       0
# HOUR_COS                       0
# MONTH_SIN                      0
# MONTH_COS                      0
# DAY_OF_WEEK_SIN                0
# DAY_OF_WEEK_COS                0
# dtype: int64

# %%
df2['PERP_SEX'].fillna('UNKNOWN', inplace=True)
df2['PERP_RACE'].fillna('UNKNOWN', inplace=True)

# %%
df2.isnull().sum()
# Out:
# BORO                           0
# PRECINCT                       0
# JURISDICTION_CODE              2
# LOCATION_DESC              14977
# STATISTICAL_MURDER_FLAG        0
# PERP_AGE_GROUP              9344
# PERP_SEX                       0
# PERP_RACE                      0
# VIC_AGE_GROUP                  0
# VIC_SEX                        0
# VIC_RACE                       0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                      10
# Longitude                     10
# Lon_Lat                       10
# Year                           0
# HOUR_SIN                       0
# HOUR_COS                       0
# MONTH_SIN                      0
# MONTH_COS                      0
# DAY_OF_WEEK_SIN                0
# DAY_OF_WEEK_COS                0
# dtype: int64

# %%
age_group_map = {
    '<18': 15,
    '18-24': 21,
    '25-44': 35,
    '45-64': 55,
    '65+': 70,
}

df2['PERP_AGE_NUMERIC'] = df2['PERP_AGE_GROUP'].map(age_group_map)

# %%
# Fill UNKNOWNs with the mean of the known values
mean_age = df2['PERP_AGE_NUMERIC'].mean()
df2['PERP_AGE_NUMERIC'].fillna(mean_age, inplace=True)

# %%
df2.isnull().sum()
# Out:
# BORO                           0
# PRECINCT                       0
# JURISDICTION_CODE              2
# LOCATION_DESC              14977
# STATISTICAL_MURDER_FLAG        0
# PERP_AGE_GROUP              9344
# PERP_SEX                       0
# PERP_RACE                      0
# VIC_AGE_GROUP                  0
# VIC_SEX                        0
# VIC_RACE                       0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                      10
# Longitude                     10
# Lon_Lat                       10
# Year                           0
# HOUR_SIN                       0
# HOUR_COS                       0
# MONTH_SIN                      0
# MONTH_COS                      0
# DAY_OF_WEEK_SIN                0
# DAY_OF_WEEK_COS                0
# PERP_AGE_NUMERIC               0
# dtype: int64

# %%
df2.drop(columns=['PERP_AGE_GROUP', 'Latitude', 'Lon_Lat','X_COORD_CD','Y_COORD_CD','Longitude'], inplace=True)

# %%
df2['LOCATION_DESC'].value_counts()
# Out:
# LOCATION_DESC
# MULTI DWELL - PUBLIC HOUS    4832
# MULTI DWELL - APT BUILD      2835
# (null)                        977
# PVT HOUSE                     951
# GROCERY/BODEGA                694
# BAR/NIGHT CLUB                628
# COMMERCIAL BLDG               292
# RESTAURANT/DINER              204
# NONE                          175
# BEAUTY/NAIL SALON             112
# FAST FOOD                     104
# SOCIAL CLUB/POLICY LOCATI      72
# GAS STATION                    71
# HOSPITAL                       65
# LIQUOR STORE                   41
# SMALL MERCHANT                 37
# STORE UNCLASSIFIED             36
# HOTEL/MOTEL                    35
# DRY CLEANER/LAUNDRY            31
# SUPERMARKET                    21
# DRUG STORE                     14
# CLOTHING BOUTIQUE              14
# JEWELRY STORE                  12
# TELECOMM. STORE                11
# VARIETY STORE                  11
# SHOE STORE                     10
# DEPT STORE                      9
# ...

# %%
df2['LOCATION_DESC'] = df2['LOCATION_DESC'].replace({'(null)': 'UNKNOWN', 'NONE': 'UNKNOWN'})

# %%
# Count the value frequencies
location_counts = df2['LOCATION_DESC'].value_counts()

# Set threshold (e.g., keep top 7 most frequent)
top_locations = location_counts[location_counts > 200].index

# Replace all others with 'OTHER'
df2['LOCATION_DESC_GROUPED'] = df2['LOCATION_DESC'].apply(
    lambda x: 'UNKNOWN' if pd.isna(x) else (x if x in top_locations else 'OTHER')
)

# %%
df2['LOCATION_DESC'].value_counts()
# Out:
# LOCATION_DESC
# MULTI DWELL - PUBLIC HOUS    4832
# MULTI DWELL - APT BUILD      2835
# UNKNOWN                      1152
# PVT HOUSE                     951
# GROCERY/BODEGA                694
# BAR/NIGHT CLUB                628
# COMMERCIAL BLDG               292
# RESTAURANT/DINER              204
# BEAUTY/NAIL SALON             112
# FAST FOOD                     104
# SOCIAL CLUB/POLICY LOCATI      72
# GAS STATION                    71
# HOSPITAL                       65
# LIQUOR STORE                   41
# SMALL MERCHANT                 37
# STORE UNCLASSIFIED             36
# HOTEL/MOTEL                    35
# DRY CLEANER/LAUNDRY            31
# SUPERMARKET                    21
# DRUG STORE                     14
# CLOTHING BOUTIQUE              14
# JEWELRY STORE                  12
# TELECOMM. STORE                11
# VARIETY STORE                  11
# SHOE STORE                     10
# DEPT STORE                      9
# FACTORY/WAREHOUSE               8
# ...

# %%
df2['LOCATION_DESC_GROUPED'].value_counts()
# Out:
# LOCATION_DESC_GROUPED
# UNKNOWN                      16129
# MULTI DWELL - PUBLIC HOUS     4832
# MULTI DWELL - APT BUILD       2835
# PVT HOUSE                      951
# OTHER                          747
# GROCERY/BODEGA                 694
# BAR/NIGHT CLUB                 628
# COMMERCIAL BLDG                292
# RESTAURANT/DINER               204
# Name: count, dtype: int64

# %%
df2.isnull().sum()
# Out:
# BORO                           0
# PRECINCT                       0
# JURISDICTION_CODE              2
# LOCATION_DESC              14977
# STATISTICAL_MURDER_FLAG        0
# PERP_SEX                       0
# PERP_RACE                      0
# VIC_AGE_GROUP                  0
# VIC_SEX                        0
# VIC_RACE                       0
# Year                           0
# HOUR_SIN                       0
# HOUR_COS                       0
# MONTH_SIN                      0
# MONTH_COS                      0
# DAY_OF_WEEK_SIN                0
# DAY_OF_WEEK_COS                0
# PERP_AGE_NUMERIC               0
# LOCATION_DESC_GROUPED          0
# dtype: int64

# %%
df2= df2.drop(columns='LOCATION_DESC')

# %%
df2['VIC_AGE_GROUP'].value_counts()
# Out:
# VIC_AGE_GROUP
# 25-44      12281
# 18-24      10086
# <18         2839
# 45-64       1863
# 65+          181
# UNKNOWN       61
# 1022           1
# Name: count, dtype: int64

# %%
# First, remove the invalid value
df2 = df2[df2['VIC_AGE_GROUP'] != '1022']

# Define a mapping from group to approximate numerical age (you can adjust midpoints if needed)
age_mapping = {
    '<18': 15,
    '18-24': 21,
    '25-44': 35,
    '45-64': 55,
    '65+': 70,
    'UNKNOWN': None  # Keep as None/NaN for now, can fill or drop later
}

# Create a new column with numerical values
df2['VIC_AGE_NUM'] = df2['VIC_AGE_GROUP'].map(age_mapping)

# %%
df2['VIC_AGE_NUM'].value_counts()
# Out:
# VIC_AGE_NUM
# 35.0    12281
# 21.0    10086
# 15.0     2839
# 55.0     1863
# 70.0      181
# Name: count, dtype: int64

# %%
df2['PERP_RACE'].value_counts()
# Out:
# PERP_RACE
# UNKNOWN           11786
# BLACK             11431
# WHITE HISPANIC     2341
# BLACK HISPANIC     1314
# WHITE               283
# OTHER               156
# Name: count, dtype: int64

# %%
df2= df2.drop(columns='VIC_AGE_GROUP')

# %%
df2.shape
# Out:
# (27311, 18)

# %%
df2.duplicated().sum()
# Out:
# 16

# %%
df2[df2.duplicated()]
# Out:
#            BORO  PRECINCT  JURISDICTION_CODE  STATISTICAL_MURDER_FLAG  \
# 8550      BRONX        40                2.0                    False
# 12344    QUEENS       113                0.0                    False
# 15581    QUEENS       103                0.0                    False
# 15659  BROOKLYN        67                0.0                    False
# 17096     BRONX        47                0.0                    False
# 17794  BROOKLYN        67                0.0                    False
# 18595  BROOKLYN        73                2.0                    False
# 19065    QUEENS       101                0.0                    False
# 19687  BROOKLYN        73                0.0                    False
# 21550  BROOKLYN        75                0.0                    False
# 22006  BROOKLYN        67                0.0                    False
# 22028  BROOKLYN        71                0.0                    False
# ...

# %%
df2['STATISTICAL_MURDER_FLAG'] = df2['STATISTICAL_MURDER_FLAG'].map({False: 0, True: 1})

# %%
df2['STATISTICAL_MURDER_FLAG'].value_counts()
# Out:
# STATISTICAL_MURDER_FLAG
# 0    22045
# 1     5266
# Name: count, dtype: int64

# %%
df2.describe()
# Out:
#            PRECINCT  JURISDICTION_CODE  STATISTICAL_MURDER_FLAG          Year  \
# count  27311.000000       27309.000000             27311.000000  27311.000000
# mean      65.637289           0.326925                 0.192816   2013.492183
# std       27.304347           0.737754                 0.394517      5.142923
# min        1.000000           0.000000                 0.000000   2006.000000
# 25%       44.000000           0.000000                 0.000000   2009.000000
# 50%       68.000000           0.000000                 0.000000   2013.000000
# 75%       81.000000           0.000000                 0.000000   2018.000000
# max      123.000000           2.000000                 1.000000   2022.000000
#
#            HOUR_SIN      HOUR_COS     MONTH_SIN     MONTH_COS  \
# count  27311.000000  2.731100e+04  2.731100e+04  27311.000000
# mean      -0.168555  3.811129e-01 -1.157060e-01     -0.126441
# std        0.645496  6.400836e-01  6.854096e-01      0.707725
# ...

# %%
df2.head()
# Out:
#      BORO  PRECINCT  JURISDICTION_CODE  STATISTICAL_MURDER_FLAG PERP_SEX  \
# 0  QUEENS       105                0.0                        0  UNKNOWN
# 1   BRONX        40                0.0                        0  UNKNOWN
# 2  QUEENS       108                0.0                        1  UNKNOWN
# 3   BRONX        44                0.0                        0  UNKNOWN
# 4   BRONX        47                0.0                        1        M
#
#   PERP_RACE VIC_SEX        VIC_RACE  Year  HOUR_SIN      HOUR_COS  \
# 0   UNKNOWN       M           BLACK  2021 -0.707107  7.071068e-01
# 1   UNKNOWN       M           BLACK  2014 -0.965926 -2.588190e-01
# 2   UNKNOWN       M           WHITE  2015  0.707107  7.071068e-01
# 3   UNKNOWN       M  WHITE HISPANIC  2015 -1.000000 -1.836970e-16
# 4     BLACK       M           BLACK  2009 -0.500000  8.660254e-01
#
#       MONTH_SIN  MONTH_COS  DAY_OF_WEEK_SIN  DAY_OF_WEEK_COS  \
# 0  5.000000e-01  -0.866025         0.433884        -0.900969
# ...

# %%
df2.isnull().sum()
# Out:
# BORO                        0
# PRECINCT                    0
# JURISDICTION_CODE           2
# STATISTICAL_MURDER_FLAG     0
# PERP_SEX                    0
# PERP_RACE                   0
# VIC_SEX                     0
# VIC_RACE                    0
# Year                        0
# HOUR_SIN                    0
# HOUR_COS                    0
# MONTH_SIN                   0
# MONTH_COS                   0
# DAY_OF_WEEK_SIN             0
# DAY_OF_WEEK_COS             0
# PERP_AGE_NUMERIC            0
# LOCATION_DESC_GROUPED       0
# VIC_AGE_NUM                61
# dtype: int64

# %%
df3 = df2.dropna()

# %%
df3.isnull().sum()
# Out:
# BORO                       0
# PRECINCT                   0
# JURISDICTION_CODE          0
# STATISTICAL_MURDER_FLAG    0
# PERP_SEX                   0
# PERP_RACE                  0
# VIC_SEX                    0
# VIC_RACE                   0
# Year                       0
# HOUR_SIN                   0
# HOUR_COS                   0
# MONTH_SIN                  0
# MONTH_COS                  0
# DAY_OF_WEEK_SIN            0
# DAY_OF_WEEK_COS            0
# PERP_AGE_NUMERIC           0
# LOCATION_DESC_GROUPED      0
# VIC_AGE_NUM                0
# dtype: int64

# %%
df3.shape
# Out:
# (27248, 18)

# %%
df2.columns
# Out:
# Index(['BORO', 'PRECINCT', 'JURISDICTION_CODE', 'STATISTICAL_MURDER_FLAG',
#        'PERP_SEX', 'PERP_RACE', 'VIC_SEX', 'VIC_RACE', 'Year', 'HOUR_SIN',
#        'HOUR_COS', 'MONTH_SIN', 'MONTH_COS', 'DAY_OF_WEEK_SIN',
#        'DAY_OF_WEEK_COS', 'PERP_AGE_NUMERIC', 'LOCATION_DESC_GROUPED',
#        'VIC_AGE_NUM'],
#       dtype='object')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27248 entries, 0 to 27311
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   BORO                     27248 non-null  object
#  1   PRECINCT                 27248 non-null  int64
#  2   JURISDICTION_CODE        27248 non-null  float64
#  3   STATISTICAL_MURDER_FLAG  27248 non-null  int64
#  4   PERP_SEX                 27248 non-null  object
#  5   PERP_RACE                27248 non-null  object
#  6   VIC_SEX                  27248 non-null  object
#  7   VIC_RACE                 27248 non-null  object
#  8   Year                     27248 non-null  int32
#  9   HOUR_SIN                 27248 non-null  float64
#  10  HOUR_COS                 27248 non-null  float64
#  11  MONTH_SIN                27248 non-null  float64
#  12  MONTH_COS                27248 non-null  float64
#  13  DAY_OF_WEEK_SIN          27248 non-null  float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=df3, x='STATISTICAL_MURDER_FLAG')
plt.title('Fatal vs Non-Fatal Shootings')
# Out:
# Text(0.5, 1.0, 'Fatal vs Non-Fatal Shootings')

# %%
sns.countplot(data=df3, x='BORO', hue='STATISTICAL_MURDER_FLAG')
plt.title('Shootings per Borough by Fatality')
# Out:
# Text(0.5, 1.0, 'Shootings per Borough by Fatality')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df3, x='STATISTICAL_MURDER_FLAG', y='PRECINCT')
plt.title('Precincts Distribution by Fatality')
# Out:
# Text(0.5, 1.0, 'Precincts Distribution by Fatality')

# %%
for col in ['PERP_SEX', 'PERP_RACE', 'VIC_SEX', 'VIC_RACE']:
    sns.countplot(data=df3, x=col, hue='STATISTICAL_MURDER_FLAG')
    plt.title(f'{col} vs Fatality')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Convert polar back to angle if needed
import numpy as np
df3['HOUR'] = np.arctan2(df3['HOUR_SIN'], df3['HOUR_COS']) * (12 / np.pi)
df3['HOUR'] = df3['HOUR'] % 24

sns.histplot(data=df3, x='HOUR', bins=24, kde=True)
plt.title('Shooting Hour Distribution')
# Out:
# Text(0.5, 1.0, 'Shooting Hour Distribution')

# %%
sns.countplot(data=df3, y='LOCATION_DESC_GROUPED', order=df2['LOCATION_DESC_GROUPED'].value_counts().index)
plt.title('Shooting Locations')
# Out:
# Text(0.5, 1.0, 'Shooting Locations')

# %%
sns.histplot(data=df3, x='PERP_AGE_NUMERIC', hue='STATISTICAL_MURDER_FLAG', kde=True, bins=30)
plt.title('Perpetrator Age Distribution by Fatality')

sns.histplot(data=df3, x='VIC_AGE_NUM', hue='STATISTICAL_MURDER_FLAG', kde=True, bins=30)
plt.title('Victim Age Distribution by Fatality')
# Out:
# Text(0.5, 1.0, 'Victim Age Distribution by Fatality')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df3[['PERP_AGE_NUMERIC', 'VIC_AGE_NUM']])
plt.title("Boxplot: Perpetrator vs Victim Age")
plt.ylabel("Age")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df3.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Feature Correlations')
# Out:
# Text(0.5, 1.0, 'Feature Correlations')

# %%
fatality_rate = df3.groupby('BORO')['STATISTICAL_MURDER_FLAG'].mean().sort_values(ascending=False)
fatality_rate.plot(kind='bar', title='Fatality Rate by Borough')
# Out:
# <Axes: title={'center': 'Fatality Rate by Borough'}, xlabel='BORO'>

# %%
df3.head()
# Out:
#      BORO  PRECINCT  JURISDICTION_CODE  STATISTICAL_MURDER_FLAG PERP_SEX  \
# 0  QUEENS       105                0.0                        0  UNKNOWN
# 1   BRONX        40                0.0                        0  UNKNOWN
# 2  QUEENS       108                0.0                        1  UNKNOWN
# 3   BRONX        44                0.0                        0  UNKNOWN
# 4   BRONX        47                0.0                        1        M
#
#   PERP_RACE VIC_SEX        VIC_RACE  Year  HOUR_SIN      HOUR_COS  \
# 0   UNKNOWN       M           BLACK  2021 -0.707107  7.071068e-01
# 1   UNKNOWN       M           BLACK  2014 -0.965926 -2.588190e-01
# 2   UNKNOWN       M           WHITE  2015  0.707107  7.071068e-01
# 3   UNKNOWN       M  WHITE HISPANIC  2015 -1.000000 -1.836970e-16
# 4     BLACK       M           BLACK  2009 -0.500000  8.660254e-01
#
#       MONTH_SIN  MONTH_COS  DAY_OF_WEEK_SIN  DAY_OF_WEEK_COS  \
# 0  5.000000e-01  -0.866025         0.433884        -0.900969
# ...

# %%
df3= df3.drop(columns='HOUR')

# %%
for col in df3.columns:
    print(f"{col} ({df3[col].nunique()} unique values):")
    print(df3[col].unique())
    print("-" * 50)
# Out:
# BORO (5 unique values):
# ['QUEENS' 'BRONX' 'BROOKLYN' 'MANHATTAN' 'STATEN ISLAND']
# --------------------------------------------------
# PRECINCT (77 unique values):
# [105  40 108  44  47  81 114 101  23  75  71  50  78  30  73  84  90  60
#   48 106  28  79 120  34 103  13  83  49  67  52  63 110  41  42  43  26
#   77  25  76  14 113  24  69  46  32  45   9  62   7  33 104  61  72  88
#   70  10 102  17 115 100   6 107   5 121  94 122  18 109  66  19   1 123
#   20  22 112  68 111]
# --------------------------------------------------
# JURISDICTION_CODE (3 unique values):
# [0. 2. 1.]
# --------------------------------------------------
# STATISTICAL_MURDER_FLAG (2 unique values):
# [0 1]
# --------------------------------------------------
# PERP_SEX (3 unique values):
# ['UNKNOWN' 'M' 'F']
# --------------------------------------------------
# PERP_RACE (6 unique values):
# ['UNKNOWN' 'BLACK' 'BLACK HISPANIC' 'OTHER' 'WHITE HISPANIC' 'WHITE']
# ...

# %%
categorical_cols = ['BORO', 'PERP_SEX', 'PERP_RACE', 'VIC_SEX', 'VIC_RACE', 'LOCATION_DESC_GROUPED']

df_encoded = pd.get_dummies(df3, columns=categorical_cols, drop_first=True)

# %%
df_encoded.head()
# Out:
#    PRECINCT  JURISDICTION_CODE  STATISTICAL_MURDER_FLAG  Year  HOUR_SIN  \
# 0       105                0.0                        0  2021 -0.707107
# 1        40                0.0                        0  2014 -0.965926
# 2       108                0.0                        1  2015  0.707107
# 3        44                0.0                        0  2015 -1.000000
# 4        47                0.0                        1  2009 -0.500000
#
#        HOUR_COS     MONTH_SIN  MONTH_COS  DAY_OF_WEEK_SIN  DAY_OF_WEEK_COS  \
# 0  7.071068e-01  5.000000e-01  -0.866025         0.433884        -0.900969
# 1 -2.588190e-01  1.224647e-16  -1.000000        -0.433884        -0.900969
# 2  7.071068e-01 -5.000000e-01   0.866025        -0.974928        -0.222521
# 3 -1.836970e-16 -8.660254e-01   0.500000        -0.433884        -0.900969
# 4  8.660254e-01  8.660254e-01   0.500000         0.433884        -0.900969
#
#    ...  VIC_RACE_WHITE  VIC_RACE_WHITE HISPANIC  \
# ...

# %%
X = df_encoded.drop('STATISTICAL_MURDER_FLAG', axis=1)
y = df_encoded['STATISTICAL_MURDER_FLAG']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)


from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Initialize the models
rf_model = RandomForestClassifier(random_state=42)
dt_model = DecisionTreeClassifier(random_state=42)
lr_model = LogisticRegression(random_state=42)

# Train the models
models = [rf_model, dt_model, lr_model]
model_names = ['Random Forest', 'Decision Tree', 'Logistic Regression']

# Evaluate the models using cross-validation
for model, name in zip(models, model_names):
    print(f"Evaluating {name}...")
    
    # Cross-validation score (using accuracy here as an example)
    cv_score = cross_val_score(model, X_train_res, y_train_res, cv=5, scoring='accuracy')
    print(f"{name} CV Accuracy: {cv_score.mean():.4f} (+/- {cv_score.std():.4f})")


from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Define a grid of hyperparameters to try
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True]
}

# Initialize the model
rf = RandomForestClassifier(random_state=42, class_weight='balanced')

# Grid Search with 5-fold cross-validation
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
                           cv=5, n_jobs=-1,scoring='recall', verbose=2)

# Fit the grid search to the training data
grid_search.fit(X_train_res, y_train_res)

# Print the best parameters and best accuracy
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation accuracy: ", grid_search.best_score_)


from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Use the best model from GridSearchCV
best_rf = grid_search.best_estimator_

# Predict on test data
y_pred = best_rf.predict(X_test)
y_prob = best_rf.predict_proba(X_test)[:, 1]  # Probability for ROC AUC

# Evaluation Metrics
print("\n📊 Classification Report:")
print(classification_report(y_test, y_pred))

print("📌 Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print(f"🎯 ROC AUC Score: {roc_auc_score(y_test, y_prob):.4f}")

# %%
import matplotlib.pyplot as plt
import pandas as pd

importances = best_rf.feature_importances_
feature_names = X.columns
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
top_features = importance_df.sort_values(by='Importance', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.barh(top_features['Feature'][::-1], top_features['Importance'][::-1])
plt.title("Top 10 Important Features Influencing Fatality")
plt.xlabel("Importance Score")
plt.tight_layout()
plt.show()

# %%
# Display the top 10 features with their importance scores
print(top_features)
# Out:
#              Feature  Importance
# 4           HOUR_COS    0.095971
# 7    DAY_OF_WEEK_SIN    0.094017
# 6          MONTH_COS    0.092344
# 3           HOUR_SIN    0.089945
# 5          MONTH_SIN    0.089617
# 8    DAY_OF_WEEK_COS    0.089436
# 0           PRECINCT    0.071028
# 2               Year    0.066956
# 10       VIC_AGE_NUM    0.034467
# 9   PERP_AGE_NUMERIC    0.030277

# %%
# For Hour - Reversing the sine and cosine transformation
df_encoded['HOUR_REVERSED'] = (np.arctan2(df_encoded['HOUR_SIN'], df_encoded['HOUR_COS']) / (2 * np.pi)) * 24
df_encoded['HOUR_REVERSED'] = (df_encoded['HOUR_REVERSED'] + 24) % 24  # Normalize between 0 and 24
df_encoded['HOUR_REVERSED'] = df_encoded['HOUR_REVERSED'].round().astype(int)  # Round to nearest integer

# For Day of the Week - Reversing the sine and cosine transformation
df_encoded['DAY_OF_WEEK_REVERSED'] = (np.arctan2(df_encoded['DAY_OF_WEEK_SIN'], df_encoded['DAY_OF_WEEK_COS']) / (2 * np.pi)) * 7
df_encoded['DAY_OF_WEEK_REVERSED'] = (df_encoded['DAY_OF_WEEK_REVERSED'] + 7) % 7  # Normalize between 0 and 6
df_encoded['DAY_OF_WEEK_REVERSED'] = df_encoded['DAY_OF_WEEK_REVERSED'].round().astype(int)  # Round to nearest integer

# For Month - Reversing the sine and cosine transformation
df_encoded['MONTH_REVERSED'] = (np.arctan2(df_encoded['MONTH_SIN'], df_encoded['MONTH_COS']) / (2 * np.pi)) * 12
df_encoded['MONTH_REVERSED'] = (df_encoded['MONTH_REVERSED'] + 12) % 12  # Normalize between 0 and 12
df_encoded['MONTH_REVERSED'] = df_encoded['MONTH_REVERSED'].round().astype(int)  # Round to nearest integer
df_encoded['MONTH_REVERSED'] = df_encoded['MONTH_REVERSED'].apply(lambda x: x if x != 0 else 12)  # Fix 0 to be 12 (December)

# %%
# Visualizing fatalities across hours using the actual HOUR_REVERSED
plt.figure(figsize=(10, 6))
sns.countplot(data=df_encoded, x='HOUR_REVERSED', hue='STATISTICAL_MURDER_FLAG', palette='coolwarm')
plt.title('Fatalities Across Hours of the Day (Actual Time)')
plt.xlabel('Hour of Day')
plt.ylabel('Count of Incidents')
plt.show()

# Visualizing fatalities across days of the week using actual day of the week
plt.figure(figsize=(10, 6))
sns.countplot(data=df_encoded, x='DAY_OF_WEEK_REVERSED', hue='STATISTICAL_MURDER_FLAG', palette='coolwarm')
plt.title('Fatalities Across Days of the Week (Actual Day)')
plt.xlabel('Day of Week')
plt.ylabel('Count of Incidents')
plt.show()

# Visualizing fatalities across months using actual month
plt.figure(figsize=(10, 6))
sns.countplot(data=df_encoded, x='MONTH_REVERSED', hue='STATISTICAL_MURDER_FLAG', palette='coolwarm')
plt.title('Fatalities Across Months (Actual Month)')
plt.xlabel('Month')
plt.ylabel('Count of Incidents')
plt.show()

# %%
# Analyzing the hour of the day and fatality rate
hour_fatalities = df_encoded.groupby('HOUR_REVERSED')['STATISTICAL_MURDER_FLAG'].mean()
print(hour_fatalities)
# Out:
# HOUR_REVERSED
# 0     0.180110
# 1     0.175000
# 2     0.172662
# 3     0.172900
# 4     0.203331
# 5     0.246790
# 6     0.238356
# 7     0.304721
# 8     0.268085
# 9     0.235023
# 10    0.231023
# 11    0.250674
# 12    0.227926
# 13    0.229565
# 14    0.203846
# 15    0.176982
# 16    0.150339
# 17    0.203929
# 18    0.225546
# 19    0.189409
# 20    0.172906
# 21    0.193384
# 22    0.206481
# 23    0.167753
# Name: STATISTICAL_MURDER_FLAG, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(24), hour_fatalities, marker='o', color='red')
plt.title("Fatalities by Hour of Day")
plt.xlabel("Hour of Day")
plt.ylabel("Mean Fatality Risk")
plt.xticks(range(24), [f'{i}:00' for i in range(24)], rotation=45)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import precision_recall_curve, ConfusionMatrixDisplay

# --- Confusion Matrix ---
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_rf.classes_)

plt.figure(figsize=(6, 5))
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix")
plt.grid(False)
plt.show()

# --- Precision-Recall Curve ---
precision, recall, thresholds = precision_recall_curve(y_test, y_prob)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', color='darkorange', lw=2)
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid(True)
plt.show()
